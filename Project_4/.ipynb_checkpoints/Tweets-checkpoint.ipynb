# %% [markdown]
# ### Import Modules

# %%
import pandas as pd
import numpy as np
import datetime
import pickle as pkl

# %% [markdown]
# ### Reduce Memory Usage

# %%
def reduce_mem_usage(props):
    start_mem_usg = props.memory_usage().sum() / 1024**2 
    print("Memory usage of properties dataframe is :",start_mem_usg," MB")
    NAlist = [] # Keeps track of columns that have missing values filled in. 
    for col in props.columns:
        if (props[col].dtype != object and props[col].dtype != 'datetime64[ns]'):  # Exclude strings
            
            # Print current column type
            print("******************************")
            print("Column: ",col)
            print("dtype before: ",props[col].dtype)
            
            # make variables for Int, max and min
            IsInt = False
            mx = props[col].max()
            mn = props[col].min()
            
            # Integer does not support NA, therefore, NA needs to be filled
            if not np.isfinite(props[col]).all(): 
                NAlist.append(col)
                props[col].fillna(mn-1,inplace=True)  
                   
            # test if column can be converted to an integer
            asint = props[col].fillna(0).astype(np.int64)
            result = (props[col] - asint)
            result = result.sum()
            if result > -0.01 and result < 0.01:
                IsInt = True

            
            # Make Integer/unsigned Integer datatypes
            if IsInt:
                if mn >= 0:
                    if mx < 255:
                        props[col] = props[col].astype(np.uint8)
                    elif mx < 65535:
                        props[col] = props[col].astype(np.uint16)
                    elif mx < 4294967295:
                        props[col] = props[col].astype(np.uint32)
                    else:
                        props[col] = props[col].astype(np.uint64)
                else:
                    if mn > np.iinfo(np.int8).min and mx < np.iinfo(np.int8).max:
                        props[col] = props[col].astype(np.int8)
                    elif mn > np.iinfo(np.int16).min and mx < np.iinfo(np.int16).max:
                        props[col] = props[col].astype(np.int16)
                    elif mn > np.iinfo(np.int32).min and mx < np.iinfo(np.int32).max:
                        props[col] = props[col].astype(np.int32)
                    elif mn > np.iinfo(np.int64).min and mx < np.iinfo(np.int64).max:
                        props[col] = props[col].astype(np.int64)    
            
            # Make float datatypes 32 bit
            else:
                props[col] = props[col].astype(np.float32)
            
            # Print new column type
            print("dtype after: ",props[col].dtype)
            print("******************************")
    
    # Print final result
    print("___MEMORY USAGE AFTER COMPLETION:___")
    mem_usg = props.memory_usage().sum() / 1024**2 
    print("Memory usage is: ",mem_usg," MB")
    print("This is ",100*mem_usg/start_mem_usg,"% of the initial size")
    return props

# %% [markdown]
# ### Load Data

# %%
tweet = pd.read_csv('Data/tweets.csv')

# %%
#Creating a timestamp for each tweet in order to be able to make an hourly count
def createtimestamp(df):
    """
    Creating a timestamp for each tweet in order to be able to make an hourly count
    """
    zeros = np.zeros(len(df))
    df['hours'] = zeros
    for i in range(len(df)):
        x = datetime.datetime.strptime(df.iloc[i].timestamp, '%Y-%m-%d %H:%M:%S')
        timestamp = pd.Timestamp(year = x.year, month = x.month, day = x.day, hour = x.hour)
        df.hours.iloc[i] = timestamp
    return df

# %%
df = createtimestamp(df)
df = reduce_mem_usage(df)
pkl.dump(df, open('timestamped', 'wb'))

# %%
#Count the tweets happening at certain hours
def hourlytweets(df):
    """
    Count the tweets happening at certain hours
    """
    df_count = df.groupby(['hours'])['tweet-id'].count()
    d = df_count.to_dict()
    df['activity'] = df['hours'].map(d)
    return df

# %%
df = hourlytweets(df)

# %%
df.info()

# %%
#Delete duplicates
def deleteretweets(df):
    df = tweet.drop_duplicates(subset = 'text', inplace = False)
    df = df[~df.text.str.contains('RT')]
    return df

# %%
df_sin = deleteretweets(df)
# Out:
#               user          fullname            tweet-id            timestamp  \
# 0   julia_vaingurt    Julia Vaingurt  746855460402302976  2016-06-25 23:59:52
# 1          haj1106            hunter  746855393695924224  2016-06-25 23:59:36
# 2           rimbit         Rimbit  ➡  746855315589652480  2016-06-25 23:59:17
# 3      coinstories      Coin Stories  746855306026680321  2016-06-25 23:59:15
# 4     bitcointonic      Julia Edling  746855274816798720  2016-06-25 23:59:08
# 5  onlineplatforms  Investors Europe  746855266210156545  2016-06-25 23:59:06
# 6         coindesk          CoinDesk  746855253518188545  2016-06-25 23:59:02
# 7        Henotsuke       Ivanov Vera  746855196186251264  2016-06-25 23:58:49
# 8        BitcoinCL  CL Bitcoin Sales  746855008163889152  2016-06-25 23:58:04
# 9       Gamerholic        Gamerholic  746854937338871808  2016-06-25 23:57:47
#
#                                           url  likes  replies  retweets  \
# 0   /julia_vaingurt/status/746855460402302976      0        0         0
# 1          /haj1106/status/746855393695924224      0        0         0
# 2           /rimbit/status/746855315589652480      0        0         0
# 3      /coinstories/status/746855306026680321      0        0         0
# 4     /bitcointonic/status/746855274816798720      1        0         1
# 5  /onlineplatforms/status/746855266210156545      0        0         0
# 6         /coindesk/status/746855253518188545     12        0        41
# 7        /Henotsuke/status/746855196186251264      0        0         0
# 8        /BitcoinCL/status/746855008163889152      0        0         0
# 9       /Gamerholic/status/746854937338871808      0        0         0
#
#                                                 text  \
# 0  Bitcoin: Pissed-off customers sue GAW Miners i...
# 1  I'm not gone lie I be staring at pplwhat btc's...
# 2  Did you miss Beyond Bitcoin Hangout? I CANNOT ...
# 3  What are the merits and risks of investing in ...
# 4  Hash Ocean #Bitcoin Cloud Mining №1 in the wor...
# 5  Tumultuous Week Fuels 30% Gain in Bitcoin and ...
# 6  The latest Bitcoin Price Index is 665.60 USD h...
# 7  http://gameofcoins.org/register/ncLLpdPQ0Ojj …...
# 8  http://club.nocroom.com  < #bitcoinclub #washi...
# 9  Gamerholic, WIN FOR A LIVING.. win #bitcoin or...
#
#                                                 html                hours  \
# 0  <p class="TweetTextSize js-tweet-text tweet-te...  2016-06-25 23:00:00
# 1  <p class="TweetTextSize js-tweet-text tweet-te...  2016-06-25 23:00:00
# 2  <p class="TweetTextSize js-tweet-text tweet-te...  2016-06-25 23:00:00
# 3  <p class="TweetTextSize js-tweet-text tweet-te...  2016-06-25 23:00:00
# 4  <p class="TweetTextSize js-tweet-text tweet-te...  2016-06-25 23:00:00
# 5  <p class="TweetTextSize js-tweet-text tweet-te...  2016-06-25 23:00:00
# 6  <p class="TweetTextSize js-tweet-text tweet-te...  2016-06-25 23:00:00
# 7  <p class="TweetTextSize js-tweet-text tweet-te...  2016-06-25 23:00:00
# 8  <p class="TweetTextSize js-tweet-text tweet-te...  2016-06-25 23:00:00
# 9  <p class="TweetTextSize js-tweet-text tweet-te...  2016-06-25 23:00:00
#
#    activity
# 0       554
# 1       554
# 2       554
# 3       554
# 4       554
# 5       554
# 6       554
# 7       554
# 8       554
# 9       554

# %%
text = tweet1['text'].reset_index()
text.dropna(inplace = True)
text1 = text.drop_duplicates()
text1[text1['text'].str.contains('rt')]
# Out:
#            index                                               text
# 10            10  Bitcoin Goes Official On New York Stock Exchan...
# 41            41  Bitcoin Price Watch; Finally Some Support? htt...
# 52            52  #Bitcoin Exchange #Coinbase Adds #Paypal Suppo...
# 65            65  Why Bitcoin users love Brexit - http://buff.ly...
# 69            69  Bitcoin Price Watch; Finally Some Support? htt...
# 84            84  Understanding the Lightning Network, Part 3: C...
# 87            87  #Start using #cryptocurrency with us right now...
# 88            88  Ned Scott @CertainAssets, co-founder of @Steem...
# 93            93  BTCTurk 2072.2 TL BTCe 636.602 $ CampBx  $ Bit...
# 99            99  New Economy Movement Market Report: XEM/BTC Up...
# 107          107  RT josephjett "#Bitcoin and the Painful Art of...
# 108          108  #18b #MonetaryUnit #Bitcoin #BTM #TheArtsFacto...
# 109          109  Bitcoin Price Index - Real-time Bitcoin Price ...
# 115          115  We become what we think about. #Marinecoin is ...
# 118          118  Bitcoin Foundation Starts Its Comeback By ... ...
# 121          121  @gooeybrains About ~$300,000 worth of BTC and ...
# 131          131  Understanding the Lightning Network, Part 3: C...
# 135          135  If you like our Digital Magazine, please consi...
# 150          150  Looks like @dannylmasters was correct in April...
# 151          151  Bitcoin Price Watch; Finally Some Support? htt...
# 161          161  #bitcoin #inglês Fortunes Will Be Made & Lost ...
# 167          167  Bitcoin Price Watch; Finally Some Support? htt...
# 170          170  Barry Silbert: "Bitcoin halving: Two weeks ™ h...
# 173          173  Fortunes Will Be Made & Lost When Capital Flee...
# 174          174  #Bitcoin and the Painful Art of Wrist Slitting...
# 177          177  [Bitcoin] Fortunes Will Be Made & Lost When Ca...
# 208          208  Buy #Bitcoin in the UK with a Debit/Credit Car...
# 217          217  One Bitcoin now worth $663.24@bitstamp. High $...
# 218          218  現在の価格は 67827円(http://blockchain.info )です。前回比は-...
# 219          219  One Bitcoin now worth $667.294. Market Cap $0....
# ...          ...                                                ...
# 1649453  1851271  Volumen monitor \n$DNT / #BTC\nPrecio actual: ...
# 1649480  1851299  [NEWS] La crypto SmartCash est maintenant disp...
# 1649503  1851324  #crypto-funded #brave #browser is about to #st...
# 1649537  1851359  LTO Network partners with http://BitMax.io  fo...
# 1649541  1851363  Er zijn veel manieren om lid te worden van de ...
# 1649545  1851369  DOGE #Vaultmex Price Alert \n Time: 2019-01-16...
# 1649555  1851382  $GDET - Press Release - In addition to Bitcoin...
# 1649556  1851383  @adeliusmancius @YoniJakarta @septi_adeliaaa C...
# 1649559  1851386  $GDET - Press Release - In addition to Bitcoin...
# 1649562  1851389  Bitcoin Price Analysis Jan.16: Stability Aroun...
# 1649576  1851406   #Robostopia Smart #CryptoCurrency Trader Bot ...
# 1649578  1851408  Top 6 BTC/USD Exchange Orderbooks: Resistance ...
# 1649586  1851416  Ethereum hard fork to drive up prices, say exp...
# 1649587  1851417  Bitcoin Price Analysis Jan.16: Stability Aroun...
# 1649588  1851418  Ethereum hard fork to drive up prices, say exp...
# 1649592  1851422  If you bought bitcoin worth $500 in 2013-08-12...
# 1649604  1851436  One Bitcoin now worth $3614.14@bitstamp. High ...
# 1649606  1851438  One Bitcoin now worth $3640.195. Market Cap $6...
# 1649617  1851449            One BTC is currently worth $3664.83 USD
# 1649634  1851466                     A $XMR is worth 0.01239385 BTC
# 1649663  1851497  #BTC #CBT #Bitmex #MarginTrading\nTRADE CALL R...
# 1649668  1851503  Participants wYould be rewarded with tokens. I...
# 1649677  1851517  BITCOIN Price | How I'm Accumulating | 3 Impor...
# 1649686  1851529  Check out how much the Bitcoin Pizza is worth ...
# 1649691  1851534  It just launched a few days ago & they are add...
# 1649693  1851536  ビットコイン(BTC)価格速報｜相場は再度下落へ　400,000円を大きく割り込む　 | C...
# 1649696  1851539  Binance has the most volume of any crypto exch...
# 1649699  1851542  Do you know what a smart contract is? Find out...
# 1649700  1851543  They feed supercomputers MASSIVE amounts of da...
# 1649712  1851555  What the #Bitcoin #Pizza is worth today!https:...
#
# [289997 rows x 2 columns]
